# %%
import pandas as pd
import seaborn as sns
import kats

# %%
df = pd.read_parquet('data/airquality.parquet')
df.sample(3)
# Out:
#                    time  fmisid  AQINDEX_PT1H_avg  PM10_PT1H_avg  \
# 188 2022-08-25 08:00:00  103140               1.0            NaN
# 302 2022-08-25 09:00:00  107147               1.0            8.1
# 6   2022-08-25 09:00:00  100662               2.0            8.4
#
#      PM25_PT1H_avg  O3_PT1H_avg  CO_PT1H_avg  SO2_PT1H_avg  NO2_PT1H_avg  \
# 188            NaN          NaN          NaN           0.4           NaN
# 302            3.4          NaN          NaN           NaN           8.4
# 6              4.1         61.9          NaN           1.2           5.3
#
#      TRSC_PT1H_avg
# 188            0.0
# 302            NaN
# 6              NaN

# %%
sns.set_theme(style="darkgrid")

# %%
sns.lineplot(data=df, x='time', y='PM10_PT1H_avg', hue="fmisid")
# Out:
# <AxesSubplot:xlabel='time', ylabel='PM10_PT1H_avg'>
